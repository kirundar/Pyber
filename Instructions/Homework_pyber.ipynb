# %%
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd
from pylab import *
from scipy import *

city_data = pd.read_csv("Pyber/raw_data/city_data.csv")
ride_data = pd.read_csv("Pyber/raw_data/ride_data.csv")

# %%
ride_data.groupby(['city','fare']).mean()
# Out:
#                            ride_id
# city           fare
# Alvarezhaven   4.07   6.100187e+12
#                5.16   2.233026e+12
#                5.34   1.108172e+12
#                6.42   8.394540e+12
#                6.45   8.939752e+12
#                6.72   6.152999e+12
#                9.87   2.747592e+12
#                14.25  6.431434e+12
#                17.67  3.829337e+12
#                18.09  1.197330e+12
#                20.23  4.348900e+12
#                20.61  8.307812e+12
#                20.74  3.574212e+11
#                20.88  9.456788e+12
#                22.54  6.435260e+12
#                22.83  3.565582e+12
#                24.16  9.047320e+12
#                27.51  6.282666e+12
#                31.08  7.413831e+12
#                31.74  5.487021e+12
#                31.82  7.948247e+12
#                31.93  4.267016e+12
#                32.46  8.586315e+11
#                33.31  3.060544e+11
#                33.62  8.974645e+12
# ...

# %%
#Total number of rides per city

Ride_totals=ride_data['ride_id'].count()
ride_data['ride_id'].count()
# Out:
# 2375

# %%
Ride_totals= len(ride_data['city'].unique())
ride_data['ride_id'].unique()
# Out:
# array([5403689035038, 4036272335942, 3645042422587, ..., 4165974278063,
#        4336212615821, 5702608059064], dtype=int64)

# %%
Ride_totals=ride_data['city'].value_counts()['ride_id']
ride_data['ride_id'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2482             try:
# -> 2483                 return libts.get_value_box(s, key)
#    2484             except IndexError:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.get_value_box (pandas\_libs\tslib.c:18843)()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.get_value_box (pandas\_libs\tslib.c:18477)()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-3d8e7ef9ee81> in <module>()
# ----> 1 Ride_totals=ride_data['city'].value_counts()['ride_id']
#       2 ride_data['ride_id'].value_counts()
#
# ...
